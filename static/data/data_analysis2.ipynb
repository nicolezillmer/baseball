# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pitching_age = pd.read_csv('final_data/FINAL_pitching_age.csv', encoding='utf-8')

# %%
# Seperate stats into DF, by type.
#ERA, WHIP, AGE
pitching_age.drop(pitching_age.columns.difference(['PLAYER','AGE00',
       'AGE01', 'AGE02', 'AGE03', 'AGE04', 'AGE05', 'AGE06', 'AGE07', 'AGE08',
       'AGE09', 'AGE10', 'AGE11', 'AGE12', 'AGE13', 'AGE14', 'AGE15', 'AGE16',
       'AGE17', 'AGE18', 'AGE19','BirthCountry']),1, inplace=True)
pitching_age
# Out:
#                PLAYER BirthCountry  AGE00  AGE01  AGE02  AGE03  AGE04  AGE05  \
# 0      Brian Anderson          USA      7      8      9     10     11     12
# 1        Zack Greinke          USA     16     17     18     19     20     21
# 2    Justin Verlander          USA     17     18     19     20     21     22
# 3         Cole Hamels          USA     16     17     18     19     20     21
# 4     Adam Wainwright          USA     19     20     21     22     23     24
# ..                ...          ...    ...    ...    ...    ...    ...    ...
# 194   Jeff Samardzija     Colombia     15     16     17     18     19     20
# 195    Andrew Cashner          USA     14     15     16     17     18     19
# 196     Jose Quintana       Mexico     11     12     13     14     15     16
# 197     Chris Tillman          USA     12     13     14     15     16     17
# 198     Marco Estrada       Mexico     17     18     19     20     21     22
#
# ...

# %%
pitching_age.groupby(by="BirthCountry").mean()
# Out:
#                         AGE00      AGE01      AGE02      AGE03      AGE04  \
# BirthCountry
# Aruba               26.000000  27.000000  28.000000  29.000000  30.000000
# Canada              28.000000  29.000000  30.000000  31.000000  32.000000
# Colombia            12.000000  13.000000  14.000000  15.000000  16.000000
# Cuba                26.500000  27.500000  28.500000  29.500000  30.500000
# Dominican Republic  22.230769  23.230769  24.230769  25.230769  26.230769
# Germany             18.000000  19.000000  20.000000  21.000000  22.000000
# Jamaica             14.000000  15.000000  16.000000  17.000000  18.000000
# Japan               17.250000  18.250000  19.250000  20.250000  21.250000
# Mexico              19.000000  20.000000  21.000000  22.000000  23.000000
# Nicaragua           23.000000  24.000000  25.000000  26.000000  27.000000
# Puerto Rico         24.500000  25.500000  26.500000  27.500000  28.500000
# ...

# %%
pitching_whip = pd.read_csv('final_data/FINAL_pitching_age.csv', encoding='utf-8')

# %%
pitching_whip.drop(pitching_whip.columns.difference(['PLAYER','whip00', 'whip01', 'whip02', 'whip03', 'whip04', 'whip05',
                                                          'whip06', 'whip07','whip08', 'whip09', 'whip10', 'whip11', 'whip12', 'whip13',
                                                          'whip14', 'whip15','whip16', 'whip17', 'whip18', 'whip19','BirthCountry']),1, inplace=True)
pitching_whip
# Out:
#                PLAYER      whip00  whip01      whip02      whip03      whip04  \
# 0      Brian Anderson  111.215392     NaN  115.384615  114.604462  134.337349
# 1        Zack Greinke         NaN     NaN         NaN         NaN         NaN
# 2    Justin Verlander         NaN     NaN         NaN         NaN         NaN
# 3         Cole Hamels         NaN     NaN         NaN         NaN         NaN
# 4     Adam Wainwright         NaN     NaN         NaN         NaN         NaN
# ..                ...         ...     ...         ...         ...         ...
# 194   Jeff Samardzija         NaN     NaN         NaN         NaN         NaN
# 195    Andrew Cashner         NaN     NaN         NaN         NaN         NaN
# 196     Jose Quintana         NaN     NaN         NaN         NaN         NaN
# 197     Chris Tillman         NaN     NaN         NaN         NaN         NaN
# 198     Marco Estrada         NaN     NaN         NaN         NaN         NaN
#
# ...

# %%
pitching_whip.groupby(by="BirthCountry").mean()
# Out:
#                         whip00      whip01      whip02      whip03  \
# BirthCountry
# Aruba               119.126406         NaN  107.881773   97.791798
# Canada               92.307692  101.015500  101.420872  105.993341
# Colombia                   NaN         NaN         NaN         NaN
# Cuba                112.916667  123.342175  113.425926  102.960103
# Dominican Republic  111.555722  100.213624   92.523870   97.271823
# Germany                    NaN         NaN         NaN         NaN
# Jamaica                    NaN         NaN         NaN         NaN
# Japan               119.537921  131.578947  133.024487   95.975232
# Mexico              105.069124  124.535316  106.516377  105.694037
# Nicaragua                  NaN         NaN  100.429185         NaN
# Puerto Rico          94.680851  105.357947   95.614943  104.008778
# USA                 107.427006  104.596003  103.064084  108.078806
# Venezuela           105.532787   93.492209   99.903961   93.731849
#
# ...

# %%
pitching_era = pd.read_csv('final_data/FINAL_pitching_age.csv', encoding='utf-8')

# %%
pitching_era.drop(pitching_era.columns.difference(['PLAYER','ERA00', 'ERA01', 'ERA02', 'ERA03', 'ERA04', 'ERA05',
                                                          'ERA06', 'ERA07','ERA08', 'ERA09', 'ERA10', 'ERA11', 'ERA12', 'ERA13',
                                                          'ERA14', 'ERA15','ERA16', 'ERA17', 'ERA18', 'ERA19','BirthCountry']),1, inplace=True)

# %%
pitching_era.groupby(by="BirthCountry").mean()
# Out:
#                     ERA00     ERA01  ERA02     ERA03     ERA04     ERA05  \
# BirthCountry
# Aruba               4.760       NaN  4.210  3.590000  4.710000  4.900000
# Canada              3.200  3.310000  3.480  3.990000  3.210000  3.990000
# Colombia              NaN       NaN    NaN       NaN       NaN       NaN
# Cuba                3.750  5.240000  4.380  3.200000  4.550000  3.795000
# Dominican Republic  4.650  3.493333  3.296  3.257500  4.272500  4.007500
# Germany               NaN       NaN    NaN       NaN       NaN       NaN
# Jamaica               NaN       NaN    NaN       NaN       NaN       NaN
# Japan               4.560  5.020000  5.710  2.900000  5.700000  3.770000
# Mexico              4.480  5.170000  3.875  4.475000       NaN  5.620000
# Nicaragua             NaN       NaN  3.010       NaN  3.490000  2.940000
# Puerto Rico         3.880  4.090000  2.965  4.195000  4.130000  3.480000
# USA                 4.312  4.012439  3.810  4.122281  4.202063  4.080769
# ...

# %%
pitching_age.to_csv('final_data/Pitching_Country_Age')
pitching_era.to_csv('final_data/Pitching_Country_ERA')
pitching_whip.to_csv('final_data/Pitching_Country_whip')

# %%
batting_age = pd.read_csv('final_data/FINAL_batting_age.csv',encoding='utf-8')
batting_bat = pd.read_csv('final_data/FINAL_batting_age.csv',encoding='utf-8')

# %%
batting_age.drop(batting_age.columns.difference(['PLAYER','AGE00',
       'AGE01', 'AGE02', 'AGE03', 'AGE04', 'AGE05', 'AGE06', 'AGE07', 'AGE08',
       'AGE09', 'AGE10', 'AGE11', 'AGE12', 'AGE13', 'AGE14', 'AGE15', 'AGE16',
       'AGE17', 'AGE18', 'AGE19','BirthCountry']),1, inplace=True)
batting_age
# Out:
#               PLAYER BirthCountry  AGE00  AGE01  AGE02  AGE03  AGE04  AGE05  \
# 0       Dave Roberts       Panama     28     29     30     31     32     33
# 1    Ramon Hernandez  Puerto Rico     24     25     26     27     28     29
# 2    Bernie Williams          USA     32     33     34     35     36     37
# 3     Reggie Sanders          USA     32     33     34     35     36     37
# 4        Brian Giles          USA     40     41     42     43     44     45
# ..               ...          ...    ...    ...    ...    ...    ...    ...
# 595    Carlos Correa  Puerto Rico      6      7      8      9     10     11
# 596        Matt Kemp          USA     16     17     18     19     20     21
# 597      Jedd Gyorko          USA     12     13     14     15     16     17
# 598   Ryan Zimmerman          USA     16     17     18     19     20     21
# 599    Eddie Rosario  Puerto Rico      9     10     11     12     13     14
#
# ...

# %%
batting_bat.drop(batting_bat.columns.difference(['PLAYER','BA00',
       'BA01', 'BA02', 'BA03', 'BA04', 'BA05', 'BA06', 'BA07', 'BA08',
       'BA09', 'BA10', 'BA11', 'BA12', 'BA13', 'BA14', 'BA15', 'BA16',
       'BA17', 'BA18', 'BA19','BirthCountry']),1, inplace=True)
batting_bat
# Out:
#               PLAYER   BA00   BA01   BA02   BA03   BA04   BA05   BA06   BA07  \
# 0       Dave Roberts    NaN    NaN  0.277  0.250  0.254  0.275  0.293  0.260
# 1    Ramon Hernandez  0.241  0.254  0.233  0.273  0.276  0.290  0.275  0.258
# 2    Bernie Williams  0.307  0.307  0.333  0.263  0.262  0.249  0.281    NaN
# 3     Reggie Sanders  0.232  0.263  0.250  0.285  0.260  0.271  0.246    NaN
# 4        Brian Giles  0.315  0.309  0.298  0.299  0.284  0.301  0.263  0.271
# ..               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 595    Carlos Correa    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 596        Matt Kemp    NaN    NaN    NaN    NaN    NaN    NaN    NaN  0.342
# 597      Jedd Gyorko    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 598   Ryan Zimmerman    NaN    NaN    NaN    NaN    NaN    NaN  0.287  0.266
# 599    Eddie Rosario    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
batting_age.groupby(by="BirthCountry").mean()
# Out:
#                         AGE00      AGE01      AGE02      AGE03      AGE04  \
# BirthCountry
# Aruba                8.000000   9.000000  10.000000  11.000000  12.000000
# Brazil              13.000000  14.000000  15.000000  16.000000  17.000000
# Canada              21.111111  22.111111  23.111111  24.111111  25.111111
# Colombia            24.500000  25.500000  26.500000  27.500000  28.500000
# Cuba                15.846154  16.846154  17.846154  18.846154  19.846154
# Curacao             14.333333  15.333333  16.333333  17.333333  18.333333
# Dominican Republic  17.553571  18.553571  19.553571  20.553571  21.553571
# Germany             19.000000  20.000000  21.000000  22.000000  23.000000
# Japan               23.500000  24.500000  25.500000  26.500000  27.500000
# Mexico              30.500000  31.500000  32.500000  33.500000  34.500000
# Netherlands         10.000000  11.000000  12.000000  13.000000  14.000000
# ...

# %%
batting_bat.groupby(by="BirthCountry").mean()
# Out:
#                         BA00      BA01      BA02      BA03      BA04  \
# BirthCountry
# Aruba                    NaN       NaN       NaN       NaN       NaN
# Brazil                   NaN       NaN       NaN       NaN       NaN
# Canada              0.278667  0.292000  0.283000  0.289333  0.273800
# Colombia            0.257500  0.268000  0.284000  0.313500  0.275500
# Cuba                0.288000  0.273000  0.273000  0.260000  0.258000
# Curacao             0.303000  0.251000  0.264000  0.277000  0.261000
# Dominican Republic  0.293412  0.277048  0.272609  0.274857  0.279692
# Germany                  NaN       NaN       NaN       NaN       NaN
# Japan                    NaN  0.350000  0.321000  0.299500  0.314000
# Mexico              0.231000  0.241500  0.232000  0.265000  0.257500
# Netherlands              NaN       NaN       NaN       NaN       NaN
# Nicaragua                NaN       NaN       NaN       NaN       NaN
# ...

# %%
batting_age.to_csv('final_data/Batting_Country_Age')
batting_bat.to_csv('final_data/Batting_Country_BA')
