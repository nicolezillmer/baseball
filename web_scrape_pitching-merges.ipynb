# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2019/start/1"
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
header = soup.find('tr', attrs={'class':'colhead'})

columns = [col.get_text() for col in header.find_all('td')]

final_df = pd.DataFrame(columns=columns)
final_df
# Out:
# Empty DataFrame
# Columns: [, PLAYER, YRS, G, GS, CG, SH, IP, H, ER, BB, SO, W, L, SV, ERA]
# Index: []

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2019/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2019_df = final_df
season2019_df
# Out:
#                   PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W   L  \
# 0    1      Hyun-Jin Ryu   6  29  29  1  1  182.2  160   47  24  163  14   5
# 1    2      Jacob deGrom   6  32  32  0  0  204.0  154   55  44  255  11   8
# 2    3       Gerrit Cole   7  33  33  0  0  212.1  142   59  48  326  20   5
# 3    4  Justin Verlander  15  34  34  2  1  223.0  137   64  42  300  21   6
# 4    5       Mike Soroka   2  29  29  0  0  174.2  153   52  41  142  13   4
# ..  ..               ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..  ..
# 68  69      Martin Perez   8  32  29  0  0  165.1  184   94  67  135  10   7
# 69  70       Jakob Junis   3  31  31  0  0  175.1  192  102  58  164   9  14
# 70  71    Reynaldo Lopez   4  33  33  1  0  184.0  203  110  65  169  10  15
# 71  72     Yusei Kikuchi   1  32  32  1  1  161.2  195   98  50  116   6  11
# 72  73     Rick Porcello  11  32  32  0  0  174.1  198  107  45  143  14  12
#
#    SV   ERA
# 0   0  2.32
# 1   0  2.43
# 2   0  2.50
# 3   0  2.58
# 4   0  2.68
# .. ..   ...
# 68  0  5.12
# 69  0  5.24
# 70  0  5.38
# 71  0  5.46
# 72  0  5.52
#
# [73 rows x 16 columns]

# %%
season2019_df.to_csv('scraped_data/2019_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2018/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2018_df = final_df
season2018_df
# Out:
#                  PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W   L  \
# 0    1     Jacob deGrom   6  32  32  1  0  217.0  152   41  46  269  10   9
# 1    2      Blake Snell   4  31  31  0  0  180.2  112   38  64  221  21   5
# 2    3       Chris Sale  10  27  27  0  0  158.0  102   37  34  237  12   4
# 3    4     Trevor Bauer   8  28  27  0  0  175.1  134   43  57  221  12   6
# 4    5       Aaron Nola   5  33  33  0  0  212.1  149   56  58  224  17   6
# ..  ..              ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..  ..
# 73  74   Andrew Cashner  10  28  28  0  0  153.0  177   90  65   99   4  15
# 74  75  Clayton Richard  11  27  27  0  0  158.2  159   94  60  108   7  11
# 75  76      Dylan Bundy   5  31  31  1  0  171.2  188  104  54  184   8  16
# 76  77  Felix Hernandez  15  29  28  0  0  155.2  159   96  59  125   8  14
# 77  78    Lucas Giolito   4  32  32  0  0  173.1  166  118  90  125  10  13
#
#    SV   ERA
# 0   0  1.70
# 1   0  1.89
# 2   0  2.11
# 3   1  2.21
# 4   0  2.37
# .. ..   ...
# 73  0  5.29
# 74  0  5.33
# 75  0  5.45
# 76  0  5.55
# 77  0  6.13
#
# [78 rows x 16 columns]

# %%
season2018_df.to_csv('scraped_data/2018_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2017/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2017_df = final_df
season2017_df
# Out:
#                    PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W   L  \
# 0    1       Corey Kluber   9  29  29  5  3  203.2  141   51  36  265  18   4
# 1    2    Clayton Kershaw  12  27  27  1  0  175.0  136   45  30  202  18   4
# 2    3       Max Scherzer  12  31  31  2  0  200.2  126   56  55  268  16   6
# 3    4  Stephen Strasburg  10  28  28  1  1  175.1  131   49  47  204  15   4
# 4    5          Alex Wood   7  27  25  0  0  152.1  123   46  38  151  16   3
# ..  ..                ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..  ..
#
# ..  ..                ...  ..  ..  .. .. ..    ...  ...  ...  ...  ...  ..
# 94  95  Francisco Liriano  14  34  28  0  0  156.2  143   93   87  167   6
# 95  96     Ubaldo Jimenez  12  31  31  0  0  176.2  190  106   95  143   9
# 96  97         Randy Wolf  16  30  26  0  0  157.2  196   99   52  104   5
# 97  98      Luke Hochevar   9  32  32  2  1  185.1  202  118   61  144   8
# 98  99       Ricky Romero   5  32  32  1  0  181.0  198  116  105  124   9
#
#      L SV   ERA
# 0    9  0  2.53
# 1    5  0  2.56
# 2    8  0  2.64
# 3    6  0  2.73
# 4    9  0  2.78
# ..  .. ..   ...
# 94  12  0  5.34
# 95  17  0  5.40
# 96  10  0  5.65
# 97  16  0  5.73
# 98  14  0  5.77
#
# [99 rows x 16 columns]

# %%
season2012_df.to_csv('scraped_data/2012_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2011/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2011_df = final_df
season2011_df
# Out:
#                      PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W  \
# 0      1    Clayton Kershaw  12  33  33  5  2  233.1  174   59  54  248  21
# 1      2       Johnny Cueto  12  24  24  3  1  156.0  123   40  47  104   9
# 2      3       Roy Halladay  16  32  32  8  1  233.2  208   61  35  220  19
# 3      4          Cliff Lee  13  32  32  6  6  232.2  197   62  42  238  17
# 4          Justin Verlander  15  34  34  4  2  251.0  174   67  57  250  24
# ..   ...                ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..
# 102  103     Brian Duensing  10  32  28  1  1  161.2  193   94  52  115   9
# 103  104  Roberto Hernandez  11  32  32  0  0  188.2  205  110  60  109   7
# 104  105         Brad Penny  14  31  31  0  0  181.2  222  107  62   74  11
# 105  106          J.A. Happ  13  28  28  0  0  156.1  157   93  83  134   6
# 106  107        John Lackey  15  28  28  0  0  160.0  203  114  56  108  12
#
#       L SV   ERA
# 0     5  0  2.28
# 1     5  0  2.31
# 2     6  0  2.35
# 3     8  0  2.40
# 4     5  0  2.40
# ..   .. ..   ...
# 102  14  0  5.23
# 103  15  0  5.25
# 104  11  0  5.30
# 105  15  0  5.35
# 106  12  0  6.41
#
# [107 rows x 16 columns]

# %%
season2011_df.to_csv('scraped_data/2011_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2010/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2010_df = final_df
season2010_df
# Out:
#                     PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W  \
# 0      1   Felix Hernandez  15  34  34  6  1  249.2  194   63  70  232  13
# 1      2      Josh Johnson   9  28  28  1  0  183.2  155   47  48  186  11
# 2      3     Clay Buchholz  13  28  28  1  1  173.2  142   45  67  120  17
# 3      4   Adam Wainwright  14  33  33  5  2  230.1  186   62  56  213  20
# 4      5      Roy Halladay  16  33  33  9  4  250.2  231   68  30  219  21
# ..   ...               ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..
# 97    98    Javier Vazquez  14  31  26  0  0  157.1  155   93  65  121  10
# 98    99       Kyle Davies   8  32  32  1  0  183.2  206  109  80  126   8
# 99   100    Nick Blackburn   6  28  26  1  0  161.0  194   97  40   68  10
# 100  101  Jeremy Bonderman   9  30  29  0  0  171.0  187  105  60  112   8
# 101  102         Zach Duke  15  29  29  0  0  159.0  212  101  51   96   8
#
#       L SV   ERA
# 0    12  0  2.27
# 1     6  0  2.30
# 2     7  0  2.33
# 3    11  0  2.42
# 4    10  0  2.44
# ..   .. ..   ...
# 97   10  0  5.32
# 98   12  0  5.34
# 99   12  0  5.42
# 100  10  0  5.53
# 101  15  0  5.72
#
# [102 rows x 16 columns]

# %%
season2010_df.to_csv('scraped_data/2010_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2009/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2009_df = final_df
season2009_df
# Out:
#                  PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W   L  \
# 0    
# ..  ..              ...  ..  ..  .. .. ..    ...  ...  ...  ...  ...  ..  ..
# 89  90   Brian Anderson  13  35  26  2  1  166.0  217  104   53   70   6  12
# 90  91   Esteban Loaiza  14  31  27  2  1  183.0  217  116   71  117  10   7
# 91  92      Shawn Estes  13  34  34  1  0  202.0  223  131  105  117  15   8
# 92  93    Scott Elarton  10  29  29  1  1  158.2  164  104   62  103   3  11
# 93  94     Jose Acevedo   5  39  27  0  0  157.2  188  104   45  117   5  12
#
#    SV   ERA
# 0   0  2.27
# 1   0  2.60
# 2   0  2.61
# 3   0  2.70
# 4   0  2.75
# .. ..   ...
# 89  0  5.64
# 90  0  5.70
# 91  0  5.84
# 92  0  5.90
# 93  0  5.94
#
# [94 rows x 16 columns]

# %%
season2004_df.to_csv('scraped_data/2004_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2003/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2003_df = final_df
season2003_df
# Out:
#                     PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W  \
# 0      1    Pedro Martinez  18  29  29  3  0  186.2  147   46  47  206  14
# 1      2     Jason Schmidt  14  29  29  5  3  207.2  152   54  46  208  17
# 2      3       Kevin Brown  19  32  32  0  0  211.0  184   56  56  185  14
# 3      4        Mark Prior   5  30  30  3  1  211.1  183   57  50  245  18
# 4      5        Tim Hudson  17  34  34  3  2  240.0  197   72  61  162  16
# ..   ...               ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..
# 96    97  Jeremy Bonderman   9  33  28  0  0  162.0  193  100  58  108   6
# 97    98       Mike Maroth   6  33  33  1  0  193.1  231  123  50   87   9
# 98             Shawn Estes  13  29  28  1  1  152.1  182   97  83  103   8
# 99   100        Cory Lidle   9  31  31  2  0  192.2  216  123  60  112  12
# 100  101       Jeff Weaver  11  32  24  0  0  159.1  211  106  47   93   7
#
#       L SV   ERA
# 0     4  0  2.22
# 1     5  0  2.34
# 2     9  0  2.39
# 3     6  0  2.43
# 4     7  0  2.70
# ..   .. ..   ...
# 96   19  0  5.56
# 97   21  0  5.73
# 98   11  0  5.73
# 99   15  0  5.75
# 100   9  0  5.99
#
# [101 rows x 16 columns]

# %%
season2003_df.to_csv('scraped_data/2003_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2002/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2002_df = final_df
season2002_df
# Out:
#                    PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W   L  \
# 0    1     Pedro Martinez  18  30  30  2  0  199.1  144   50  40  239  20   4
# 1    2      Randy Johnson  22  35  35  8  4  260.0  197   67  71  334  24   5
# 2    3         Derek Lowe  17  32  32  1  1  219.2  166   63  48  127  21   8
# 3    4        Greg Maddux  23  34  34  0  0  199.1  194   58  45  118  16   6
# 4    5         Barry Zito  15  35  35  1  0  229.1  182   70  78  182  23   5
# ..  ..                ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..  ..
# 88  89  Brandon Duckworth   8  30  29  0  0  163.0  167   98  69  167   8   9
# 89  90    Steve W. Sparks   9  32  30  3  0  189.0  238  116  67   98   8  16
# 90  91     Scott Erickson  15  29  28  3  1  160.2  192   99  68   74   5  12
# 91  92     Esteban Loaiza  14  25  25  3  1  151.1  192   96  38   87   9  10
# 92  93       Mike Hampton  16  30  30  0  0  178.2  228  122  91   74   7  15
#
#    SV   ERA
# 0   0  2.26
# 1   0  2.32
# 2   0  2.58
# 3   0  2.62
# 4   0  2.75
# .. ..   ...
# 88  0  5.41
# 89  0  5.52
# 90  0  5.55
# 91  0  5.71
# 92  0  6.15
#
# [93 rows x 16 columns]

# %%
season2002_df.to_csv('scraped_data/2002_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2001/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2001_df = final_df
season2001_df
# Out:
#                 PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W   L SV  \
# 0    1   Randy Johnson  22  35  34  3  2  249.2  181   69  71  372  21   6  0
# 1    2  Curt Schilling  20  35  35  6  1  256.2  237   85  39  293  22   6  0
# 2    3    John Burkett  15  34  34  1  1  219.1  187   74  70  187  12  12  0
# 3    4     Greg Maddux  23  34  34  3  3  233.0  220   79  27  173  17  11  0
# 4        Freddy Garcia  15  34  34  4  3  238.2  199   81  69  163  18   6  0
# ..  ..             ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..  .. ..
# 89  90      Chris Holt   5  30  22  1  0  151.1  197   97  57   80   7   9  0
# 90  91   Jose Mercedes   8  33  31  2  0  184.0  219  119  63  123   8  17  0
# 91  92   Darren Oliver  20  28  28  1  0  154.0  189  103  65  104  11  11  0
# 92  93     Dave Mlicki  10  34  29  0  0  167.2  203  115  74   97  11  11  0
# 93  94      Dave Burba  15  32  27  1  0  150.2  188  104  54  118  10  10  0
#
#      ERA
# 0   2.49
# 1   2.98
# 2   3.04
# 3   3.05
# 4   3.05
# ..   ...
# 89  5.77
# 90  5.82
# 91  6.02
# 92  6.17
# 93  6.21
#
# [94 rows x 16 columns]

# %%
season2001_df.to_csv('scraped_data/2001_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
final_df =pd.DataFrame(columns=final_df.columns)
for i in range(1,500,50):

    url = "https://www.espn.com/mlb/history/leaders/_/type/pitching/breakdown/season/year/2000/start/{}".format(i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    players = soup.find_all('tr', attrs={'class':re.compile('row player-10-')})
    for player in players:

        stats = [stat.get_text() for stat in player.find_all('td')]

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        final_df = pd.concat([final_df, temp_df], ignore_index=True)

season2000_df = final_df
season2000_df
# Out:
#                  PLAYER YRS   G  GS CG SH     IP    H   ER  BB   SO   W   L  \
# 0    1   Pedro Martinez  18  29  29  7  4  217.0  128   42  32  284  18   6
# 1    2      Kevin Brown  19  33  33  5  1  230.0  181   66  47  216  13   6
# 2    3    Randy Johnson  22  35  35  8  3  248.2  202   73  76  347  19   7
# 3    4  Jeff C. D'Amico   8  23  23  1  1  162.1  143   48  46  101  12   7
# 4    5      Greg Maddux  23  35  35  6  3  249.1  225   83  42  190  19   9
# ..  ..              ...  ..  ..  .. .. ..    ...  ...  ...  ..  ...  ..  ..
# 93  94         Pat Rapp  10  31  30  0  0  174.0  203  114  83  106   9  12
# 94  95        Omar Daal  11  32  28  0  0  167.0  208  114  72   96   4  19
# 95  96  Chris Carpenter  15  34  27  2  0  175.1  204  122  83  113  10  12
# 96  97        Jose Lima  13  33  33  0  0  196.1  251  145  68  124   7  16
# 97  98       David Cone  17  30  29  0  0  155.0  192  119  82  120   4  14
#
#    SV   ERA
# 0   0  1.74
# 1   0  2.58
# 2   0  2.64
# 3   0  2.66
# 4   0  3.00
# .. ..   ...
# 93  0  5.90
# 94  0  6.14
# 95  0  6.26
# 96  0  6.65
# 97  0  6.91
#
# [98 rows x 16 columns]

# %%
season2000_df.to_csv('scraped_data/2000_pitching.csv', index=False, sep=',', encoding='utf-8')

# %%
#mathscoresgrade4_new = mathscoresgrade4_drop.rename(columns={'AVG_SCORE':'GR4MATH'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-3154d19f71c4> in <module>
# ----> 1 mathscoresgrade4_new = mathscoresgrade4_drop.rename(columns={'AVG_SCORE':'GR4MATH'})
#
# NameError: name 'mathscoresgrade4_drop' is not defined

# %%
season2000_df_new = season2000_df.rename(columns={'YRS':'YRS00', 'G':'G00','GS':'GS00', 'CG':'CG00', 'SH':'SH00','IP':'IP00','H':'H00','ER':'ER00','BB':'BB00','SO':'SO00','W':'W00','L':'L00','SV':'SV00','ERA':'ERA00'})

season2000_df_new.head()
# Out:
#                PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00 BB00 SO00 W00  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42   32  284  18
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66   47  216  13
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73   76  347  19
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48   46  101  12
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83   42  190  19
#
#   L00 SV00 ERA00
# 0   6    0  1.74
# 1   6    0  2.58
# 2   7    0  2.64
# 3   7    0  2.66
# 4   9    0  3.00

# %%
season2001_df_new = season2001_df.rename(columns={'YRS':'YRS01', 'G':'G01', 'GS':'GS01','CG':'CG01', 'SH':'SH01','IP':'IP01','H':'H01','ER':'ER01','BB':'BB01','SO':'SO01','W':'W01','L':'L01','SV':'SV01','ERA':'ERA01'})

season2001_df_new.head()
# Out:
#               PLAYER YRS01 G01 GS01 CG01 SH01   IP01  H01 ER01 BB01 SO01 W01  \
# 0  1   Randy Johnson    22  35   34    3    2  249.2  181   69   71  372  21
# 1  2  Curt Schilling    20  35   35    6    1  256.2  237   85   39  293  22
# 2  3    John Burkett    15  34   34    1    1  219.1  187   74   70  187  12
# 3  4     Greg Maddux    23  34   34    3    3  233.0  220   79   27  173  17
# 4      Freddy Garcia    15  34   34    4    3  238.2  199   81   69  163  18
#
#   L01 SV01 ERA01
# 0   6    0  2.49
# 1   6    0  2.98
# 2  12    0  3.04
# 3  11    0  3.05
# 4   6    0  3.05

# %%
season2002_df_new = season2002_df.rename(columns={'YRS':'YRS02', 'G':'G02', 'GS':'GS02','CG':'CG02', 'SH':'SH02','IP':'IP02','H':'H02','ER':'ER02','BB':'BB02','SO':'SO02','W':'W02','L':'L02','SV':'SV02','ERA':'ERA02'})

season2002_df_new.head()
# Out:
#               PLAYER YRS02 G02 GS02 CG02 SH02   IP02  H02 ER02 BB02 SO02 W02  \
# 0  1  Pedro Martinez    18  30   30    2    0  199.1  144   50   40  239  20
# 1  2   Randy Johnson    22  35   35    8    4  260.0  197   67   71  334  24
# 2  3      Derek Lowe    17  32   32    1    1  219.2  166   63   48  127  21
# 3  4     Greg Maddux    23  34   34    0    0  199.1  194   58   45  118  16
# 4  5      Barry Zito    15  35   35    1    0  229.1  182   70   78  182  23
#
#   L02 SV02 ERA02
# 0   4    0  2.26
# 1   5    0  2.32
# 2   8    0  2.58
# 3   6    0  2.62
# 4   5    0  2.75

# %%
season2003_df_new = season2003_df.rename(columns={'YRS':'YRS03', 'G':'G03', 'GS':'GS03', 'CG':'CG03', 'SH':'SH03','IP':'IP03','H':'H03','ER':'ER03','BB':'BB03','SO':'SO03','W':'W03','L':'L03','SV':'SV03','ERA':'ERA03'})

season2003_df_new.head()
# Out:
#               PLAYER YRS03 G03 GS03 CG03 SH03   IP03  H03 ER03 BB03 SO03 W03  \
# 0  1  Pedro Martinez    18  29   29    3    0  186.2  147   46   47  206  14
# 1  2   Jason Schmidt    14  29   29    5    3  207.2  152   54   46  208  17
# 2  3     Kevin Brown    19  32   32    0    0  211.0  184   56   56  185  14
# 3  4      Mark Prior     5  30   30    3    1  211.1  183   57   50  245  18
# 4  5      Tim Hudson    17  34   34    3    2  240.0  197   72   61  162  16
#
#   L03 SV03 ERA03
# 0   4    0  2.22
# 1   5    0  2.34
# 2   9    0  2.39
# 3   6    0  2.43
# 4   7    0  2.70

# %%
season2004_df_new = season2004_df.rename(columns={'YRS':'YRS04', 'G':'G04', 'GS':'GS04','CG':'CG04', 'SH':'SH04','IP':'IP04','H':'H04','ER':'ER04','BB':'BB04','SO':'SO04','W':'W04','L':'L04','SV':'SV04','ERA':'ERA04'})

season2004_df_new.head()
# Out:
#                PLAYER YRS04 G04 GS04 CG04 SH04   IP04  H04 ER04 BB04 SO04 W04  \
# 0  1       Jake Peavy    15  27   27    0    0  166.1  146   42   53  173  15
# 1  2    Randy Johnson    22  35   35    4    2  245.2  177   71   44  290  16
# 2  3    Johan Santana    12  34   34    1    1  228.0  156   66   54  265  20
# 3  4       Ben Sheets    10  34   34    5    0  237.0  201   71   32  264  12
# 4  5  Carlos Zambrano    12  31   31    1    1  209.2  174   64   81  188  16
#
#   L04 SV04 ERA04
# 0   6    0  2.27
# 1  14    0  2.60
# 2   6    0  2.61
# 3  14    0  2.70
# 4   8    0  2.75

# %%
season2005_df_new = season2005_df.rename(columns={'YRS':'YRS05', 'G':'G05', 'CG':'CG05', 'SH':'SH05','IP':'IP05','H':'H05','ER':'ER05','BB':'BB05','SO':'SO05','W':'W05','L':'L05','SV':'SV05','ERA':'ERA05'})

season2005_df_new.head()
# Out:
#                 PLAYER YRS05 G05  GS CG05 SH05   IP05  H05 ER05 BB05 SO05 W05  \
# 0  1     Roger Clemens    24  32  32    1    0  211.1  151   44   62  185  13
# 1  2     Andy Pettitte    18  33  33    0    0  222.1  188   59   41  171  17
# 2  3  Dontrelle Willis     9  34  34    7    5  236.1  213   69   55  170  22
# 3  4    Pedro Martinez    18  31  31    4    1  217.0  159   68   47  208  15
# 4  5   Chris Carpenter    15  33  33    7    4  241.2  204   76   51  213  21
#
#   L05 SV05 ERA05
# 0   8    0  1.87
# 1   9    0  2.39
# 2  10    0  2.63
# 3   8    0  2.82
# 4   5    0  2.83

# %%
season2006_df_new = season2006_df.rename(columns={'YRS':'YRS06', 'G':'G06', 'GS':'GS06','CG':'CG06', 'SH':'SH06','IP':'IP06','H':'H06','ER':'ER06','BB':'BB06','SO':'SO06','W':'W06','L':'L06','SV':'SV06','ERA':'ERA06'})

season2006_df_new.head()
# Out:
#                PLAYER YRS06 G06 GS06 CG06 SH06   IP06  H06 ER06 BB06 SO06 W06  \
# 0  1    Johan Santana    12  34   34    1    0  233.2  186   72   47  245  19
# 1  2       Roy Oswalt    13  33   32    2    0  220.2  220   73   38  166  15
# 2  3  Chris Carpenter    15  32   32    5    3  221.2  194   76   43  184  15
# 3  4     Josh Johnson     9  31   24    0    0  157.0  136   54   68  133  12
# 4        Brandon Webb     7  33   33    5    3  235.0  216   81   50  178  16
#
#   L06 SV06 ERA06
# 0   6    0  2.77
# 1   8    0  2.98
# 2   8    0  3.09
# 3   7    0  3.10
# 4   8    0  3.10

# %%
season2007_df_new = season2007_df.rename(columns={'YRS':'YRS07', 'G':'G07', 'GS':'GS07','CG':'CG07', 'SH':'SH07','IP':'IP07','H':'H07','ER':'ER07','BB':'BB07','SO':'SO07','W':'W07','L':'L07','SV':'SV07','ERA':'ERA07'})

season2007_df_new.head()
# Out:
#                  PLAYER YRS07 G07 GS07 CG07 SH07   IP07  H07 ER07 BB07 SO07  \
# 0  1         Jake Peavy    15  34   34    0    0  223.1  169   63   68  240
# 1  2       Brandon Webb     7  34   34    4    3  236.1  209   79   72  194
# 2           John Lackey    15  33   33    2    2  224.0  219   75   52  179
# 3  4         Brad Penny    14  33   33    0    0  208.0  199   70   73  135
# 4  5  Roberto Hernandez    11  32   32    2    1  215.0  199   73   61  137
#
#   W07 L07 SV07 ERA07
# 0  19   6    0  2.54
# 1  18  10    0  3.01
# 2  19   9    0  3.01
# 3  16   4    0  3.03
# 4  19   8    0  3.06

# %%
season2008_df_new = season2008_df.rename(columns={'YRS':'YRS08', 'G':'G08', 'GS':'GS08', 'CG':'CG08', 'SH':'SH08','IP':'IP08','H':'H08','ER':'ER08','BB':'BB08','SO':'SO08','W':'W08','L':'L08','SV':'SV08','ERA':'ERA08'})

season2008_df_new.head()
# Out:
#              PLAYER YRS08 G08 GS08 CG08 SH08   IP08  H08 ER08 BB08 SO08 W08  \
# 0  1  Johan Santana    12  34   34    3    2  234.1  206   66   63  206  16
# 1  2      Cliff Lee    13  31   31    4    2  223.1  214   63   34  170  22
# 2  3   Tim Lincecum    10  34   33    2    1  227.0  182   66   84  265  18
# 3  4    CC Sabathia    19  35   35   10    5  253.0  223   76   59  251  17
# 4  5   Roy Halladay    16  34   33    9    2  246.0  220   76   39  206  20
#
#   L08 SV08 ERA08
# 0   7    0  2.53
# 1   3    0  2.54
# 2   5    0  2.62
# 3  10    0  2.70
# 4  11    0  2.78

# %%
season2009_df_new = season2009_df.rename(columns={'YRS':'YRS09', 'G':'G09', 'GS':'GS09','CG':'CG09', 'SH':'SH09','IP':'IP09','H':'H09','ER':'ER09','BB':'BB09','SO':'SO09','W':'W09','L':'L09','SV':'SV09','ERA':'ERA09'})

season2009_df_new.head()
# Out:
#                PLAYER YRS09 G09 GS09 CG09 SH09   IP09  H09 ER09 BB09 SO09 W09  \
# 0  1     Zack Greinke    16  33   33    6    3  229.1  195   55   51  242  16
# 1  2  Chris Carpenter    15  28   28    3    1  192.2  156   48   38  144  17
# 2  3     Tim Lincecum    10  32   32    4    2  225.1  168   62   68  261  15
# 3  4  Felix Hernandez    15  34   34    2    1  238.2  200   66   71  217  19
# 4  5    Jair Jurrjens     8  34   34    0    0  215.0  186   62   75  152  14
#
#   L09 SV09 ERA09
# 0   8    0  2.16
# 1   4    0  2.24
# 2   7    0  2.48
# 3   5    0  2.49
# 4  10    0  2.60

# %%
season2010_df_new = season2010_df.rename(columns={'YRS':'YRS10', 'G':'G10', 'GS':'GS10', 'CG':'CG10', 'SH':'SH10','IP':'IP10','H':'H10','ER':'ER10','BB':'BB10','SO':'SO10','W':'W10','L':'L10','SV':'SV10','ERA':'ERA10'})

season2010_df_new.head()
# Out:
#                PLAYER YRS10 G10 GS10 CG10 SH10   IP10  H10 ER10 BB10 SO10 W10  \
# 0  1  Felix Hernandez    15  34   34    6    1  249.2  194   63   70  232  13
# 1  2     Josh Johnson     9  28   28    1    0  183.2  155   47   48  186  11
# 2  3    Clay Buchholz    13  28   28    1    1  173.2  142   45   67  120  17
# 3  4  Adam Wainwright    14  33   33    5    2  230.1  186   62   56  213  20
# 4  5     Roy Halladay    16  33   33    9    4  250.2  231   68   30  219  21
#
#   L10 SV10 ERA10
# 0  12    0  2.27
# 1   6    0  2.30
# 2   7    0  2.33
# 3  11    0  2.42
# 4  10    0  2.44

# %%
season2011_df_new = season2011_df.rename(columns={'YRS':'YRS11', 'G':'G11', 'GS':'GS11','CG':'CG11', 'SH':'SH11','IP':'IP11','H':'H11','ER':'ER11','BB':'BB11','SO':'SO11','W':'W11','L':'L11','SV':'SV11','ERA':'ERA11'})

season2011_df_new.head()
# Out:
#                 PLAYER YRS11 G11 GS11 CG11 SH11   IP11  H11 ER11 BB11 SO11  \
# 0  1   Clayton Kershaw    12  33   33    5    2  233.1  174   59   54  248
# 1  2      Johnny Cueto    12  24   24    3    1  156.0  123   40   47  104
# 2  3      Roy Halladay    16  32   32    8    1  233.2  208   61   35  220
# 3  4         Cliff Lee    13  32   32    6    6  232.2  197   62   42  238
# 4     Justin Verlander    15  34   34    4    2  251.0  174   67   57  250
#
#   W11 L11 SV11 ERA11
# 0  21   5    0  2.28
# 1   9   5    0  2.31
# 2  19   6    0  2.35
# 3  17   8    0  2.40
# 4  24   5    0  2.40

# %%
season2012_df_new = season2012_df.rename(columns={'YRS':'YRS12', 'G':'G12', 'GS':'GS12', 'CG':'CG12', 'SH':'SH12','IP':'IP12','H':'H12','ER':'ER12','BB':'BB12','SO':'SO12','W':'W12','L':'L12','SV':'SV12','ERA':'ERA12'})

season2012_df_new.head()
# Out:
#                 PLAYER YRS12 G12 GS12 CG12 SH12   IP12  H12 ER12 BB12 SO12  \
# 0  1   Clayton Kershaw    12  33   33    2    2  227.2  170   64   63  229
# 1  2       David Price    12  31   31    2    1  211.0  173   60   59  205
# 2  3  Justin Verlander    15  33   33    6    1  238.1  192   70   60  239
# 3  4       R.A. Dickey    15  34   33    5    3  233.2  192   71   54  230
# 4  5      Johnny Cueto    12  33   33    2    0  217.0  205   67   49  170
#
#   W12 L12 SV12 ERA12
# 0  14   9    0  2.53
# 1  20   5    0  2.56
# 2  17   8    0  2.64
# 3  20   6    0  2.73
# 4  19   9    0  2.78

# %%
season2013_df_new = season2013_df.rename(columns={'YRS':'YRS13', 'G':'G13','GS':'GS13', 'CG':'CG13', 'SH':'SH13','IP':'IP13','H':'H13','ER':'ER13','BB':'BB13','SO':'SO13','W':'W13','L':'L13','SV':'SV13','ERA':'ERA13'})

season2013_df_new.head()
# Out:
#                PLAYER YRS13 G13 GS13 CG13 SH13   IP13  H13 ER13 BB13 SO13 W13  \
# 0  1  Clayton Kershaw    12  33   33    3    2  236.0  164   48   52  232  16
# 1  2   Jose Fernandez     4  28   28    0    0  172.2  111   42   58  187  12
# 2  3      Matt Harvey     7  26   26    1    1  178.1  135   45   31  191   9
# 3  4   Anibal Sanchez    14  29   29    1    1  182.0  156   52   54  202  14
# 4  5     Zack Greinke    16  28   28    1    1  177.2  152   52   46  148  15
#
#   L13 SV13 ERA13
# 0   9    0  1.83
# 1   6    0  2.19
# 2   5    0  2.27
# 3   8    0  2.57
# 4   4    0  2.63

# %%
season2014_df_new = season2014_df.rename(columns={'YRS':'YRS14', 'G':'G14', 'GS':'GS14','CG':'CG14', 'SH':'SH14','IP':'IP14','H':'H14','ER':'ER14','BB':'BB14','SO':'SO14','W':'W14','L':'L14','SV':'SV14','ERA':'ERA14'})

season2014_df_new.head()
# Out:
#                PLAYER YRS14 G14 GS14 CG14 SH14   IP14  H14 ER14 BB14 SO14 W14  \
# 0  1  Clayton Kershaw    12  27   27    6    2  198.1  139   39   31  239  21
# 1  2  Felix Hernandez    15  34   34    0    0  236.0  170   56   46  248  15
# 2  3       Chris Sale    10  26   26    2    0  174.0  129   42   39  208  12
# 3  4     Johnny Cueto    12  34   34    4    2  243.2  169   61   65  242  20
# 4  5  Adam Wainwright    14  32   32    5    3  227.0  184   60   50  179  20
#
#   L14 SV14 ERA14
# 0   3    0  1.77
# 1   6    0  2.14
# 2   4    0  2.17
# 3   9    0  2.25
# 4   9    0  2.38

# %%
season2015_df_new = season2015_df.rename(columns={'YRS':'YRS15', 'G':'G15', 'GS':'GS15', 'CG':'CG15', 'SH':'SH15','IP':'IP15','H':'H15','ER':'ER15','BB':'BB15','SO':'SO15','W':'W15','L':'L15','SV':'SV15','ERA':'ERA15'})

season2015_df_new.head()
# Out:
#                PLAYER YRS15 G15 GS15 CG15 SH15   IP15  H15 ER15 BB15 SO15 W15  \
# 0  1     Zack Greinke    16  32   32    1    0  222.2  148   41   40  200  19
# 1  2     Jake Arrieta    10  33   33    4    3  229.0  150   45   48  236  22
# 2  3  Clayton Kershaw    12  33   33    4    3  232.2  163   55   42  301  16
# 3  4      David Price    12  32   32    3    1  220.1  190   60   47  225  18
# 4  5   Dallas Keuchel     8  33   33    3    2  232.0  185   64   51  216  20
#
#   L15 SV15 ERA15
# 0   3    0  1.66
# 1   6    0  1.77
# 2   7    0  2.13
# 3   5    0  2.45
# 4   8    0  2.48

# %%
season2016_df_new = season2016_df.rename(columns={'YRS':'YRS16', 'G':'G16', 'GS':'GS16','CG':'CG16', 'SH':'SH16','IP':'IP16','H':'H16','ER':'ER16','BB':'BB16','SO':'SO16','W':'W16','L':'L16','SV':'SV16','ERA':'ERA16'})

season2016_df_new.head()
# Out:
#                  PLAYER YRS16 G16 GS16 CG16 SH16   IP16  H16 ER16 BB16 SO16  \
# 0  1     Kyle Hendricks     6  31   30    2    1  190.0  142   45   44  170
# 1  2         Jon Lester    14  32   32    2    0  202.2  154   55   52  197
# 2  3   Noah Syndergaard     5  31   30    0    0  183.2  168   53   43  218
# 3  4  Madison Bumgarner    11  34   34    4    1  226.2  178   69   54  251
# 4  5       Johnny Cueto    12  32   32    5    2  219.2  195   68   45  198
#
#   W16 L16 SV16 ERA16
# 0  16   8    0  2.13
# 1  19   5    0  2.44
# 2  14   9    0  2.60
# 3  15   9    0  2.74
# 4  18   5    0  2.79

# %%
season2017_df_new = season2017_df.rename(columns={'YRS':'YRS17', 'G':'G17', 'GS':'GS17','CG':'CG17', 'SH':'SH17','IP':'IP17','H':'H17','ER':'ER17','BB':'BB17','SO':'SO17','W':'W17','L':'L17','SV':'SV17','ERA':'ERA17'})

season2017_df_new.head()
# Out:
#                  PLAYER YRS17 G17 GS17 CG17 SH17   IP17  H17 ER17 BB17 SO17  \
# 0  1       Corey Kluber     9  29   29    5    3  203.2  141   51   36  265
# 1  2    Clayton Kershaw    12  27   27    1    0  175.0  136   45   30  202
# 2  3       Max Scherzer    12  31   31    2    0  200.2  126   56   55  268
# 3  4  Stephen Strasburg    10  28   28    1    1  175.1  131   49   47  204
# 4  5          Alex Wood     7  27   25    0    0  152.1  123   46   38  151
#
#   W17 L17 SV17 ERA17
# 0  18   4    0  2.25
# 1  18   4    0  2.31
# 2  16   6    0  2.51
# 3  15   4    0  2.52
# 4  16   3    0  2.72

# %%
season2018_df_new = season2018_df.rename(columns={'YRS':'YRS18', 'G':'G18', 'GS':'GS18','CG':'CG18', 'SH':'SH18','IP':'IP18','H':'H18','ER':'ER18','BB':'BB18','SO':'SO18','W':'W18','L':'L18','SV':'SV18','ERA':'ERA18'})

season2018_df_new.head()
# Out:
#             PLAYER YRS18 G18 GS18 CG18 SH18   IP18  H18 ER18 BB18 SO18 W18  \
# 0  1  Jacob deGrom     6  32   32    1    0  217.0  152   41   46  269  10
# 1  2   Blake Snell     4  31   31    0    0  180.2  112   38   64  221  21
# 2  3    Chris Sale    10  27   27    0    0  158.0  102   37   34  237  12
# 3  4  Trevor Bauer     8  28   27    0    0  175.1  134   43   57  221  12
# 4  5    Aaron Nola     5  33   33    0    0  212.1  149   56   58  224  17
#
#   L18 SV18 ERA18
# 0   9    0  1.70
# 1   5    0  1.89
# 2   4    0  2.11
# 3   6    1  2.21
# 4   6    0  2.37

# %%
season2019_df_new = season2019_df.rename(columns={'YRS':'YRS19', 'G':'G19', 'GS':'GS19','CG':'CG19', 'SH':'SH19','IP':'IP19','H':'H19','ER':'ER19','BB':'BB19','SO':'SO19','W':'W19','L':'L19','SV':'SV19','ERA':'ERA19'})

season2019_df_new.head()
# Out:
#                 PLAYER YRS19 G19 GS19 CG19 SH19   IP19  H19 ER19 BB19 SO19  \
# 0  1      Hyun-Jin Ryu     6  29   29    1    1  182.2  160   47   24  163
# 1  2      Jacob deGrom     6  32   32    0    0  204.0  154   55   44  255
# 2  3       Gerrit Cole     7  33   33    0    0  212.1  142   59   48  326
# 3  4  Justin Verlander    15  34   34    2    1  223.0  137   64   42  300
# 4  5       Mike Soroka     2  29   29    0    0  174.2  153   52   41  142
#
#   W19 L19 SV19 ERA19
# 0  14   5    0  2.32
# 1  11   8    0  2.43
# 2  20   5    0  2.50
# 3  21   6    0  2.58
# 4  13   4    0  2.68

# %%
df1 = pd.merge(season2000_df_new, season2001_df_new, on = ['PLAYER'], how = "outer")
df1.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH01  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...    2
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...    3
#
#     IP01  H01 ER01 BB01 SO01  W01  L01 SV01 ERA01
# 0    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  249.2  181   69   71  372   21    6    0  2.49
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  233.0  220   79   27  173   17   11    0  3.05
#
# [5 rows x 31 columns]

# %%
df2 = pd.merge(df1, season2002_df_new, on = ['PLAYER'], how = "outer")

#df2.reset_index(level=0, inplace=True)
df2.head()
#df3 = pd.merge(df2, readscoresgrade4_new, on = ['STATE','YEAR'], how = "inner")
#df4 = pd.merge(df3, readscoresgrade8_new, on = ['STATE','YEAR'], how = "inner")
#df4.head(500)
#Allstatedata = pd.DataFrame(df4)
#Allstatedata.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH02  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...    0
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...    4
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...    0
#
#     IP02  H02 ER02 BB02 SO02  W02  L02 SV02 ERA02
# 0  199.1  144   50   40  239   20    4    0  2.26
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  260.0  197   67   71  334   24    5    0  2.32
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  199.1  194   58   45  118   16    6    0  2.62
#
# [5 rows x 46 columns]

# %%
df3 = pd.merge(df2, season2003_df_new, on = ['PLAYER'], how = "outer")
df3.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH03  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...    0
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...    0
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...    1
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...    0
#
#     IP03  H03 ER03 BB03 SO03  W03  L03 SV03 ERA03
# 0  186.2  147   46   47  206   14    4    0  2.22
# 1  211.0  184   56   56  185   14    9    0  2.39
# 2    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  175.1  204   93   42  100    9   16    0  4.77
# 4  218.1  225   96   33  124   16   11    0  3.96
#
# [5 rows x 61 columns]

# %%
df4 = pd.merge(df3, season2004_df_new, on = ['PLAYER'], how = "outer")
df4.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH04  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...    1
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...    2
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...    1
#
#     IP04  H04 ER04 BB04 SO04  W04  L04 SV04 ERA04
# 0  217.0  193   94   61  227   16    9    0  3.90
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  245.2  177   71   44  290   16   14    0  2.60
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  212.2  218   95   33  151   16   11    0  4.02
#
# [5 rows x 76 columns]

# %%
df5 = pd.merge(df4, season2005_df_new, on = ['PLAYER'], how = "outer")
df5.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH05  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...    1
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...    0
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...    0
#
#     IP05  H05 ER05 BB05 SO05  W05  L05 SV05 ERA05
# 0  217.0  159   68   47  208   15    8    0  2.82
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  225.2  207   95   47  211   17    8    0  3.79
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  225.0  239  106   36  136   13   15    0  4.24
#
# [5 rows x 91 columns]

# %%
df6 = pd.merge(df5, season2006_df_new, on = ['PLAYER'], how = "outer")
df6.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH06  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...    0
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...    0
#
#     IP06  H06 ER06 BB06 SO06  W06  L06 SV06 ERA06
# 0    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  205.0  194  114   60  172   17   11    0  5.00
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  210.0  219   98   37  117   15   14    0  4.20
#
# [5 rows x 106 columns]

# %%
df7 = pd.merge(df6, season2007_df_new, on = ['PLAYER'], how = "outer")
df7.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH07  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...    0
#
#     IP07  H07 ER07 BB07 SO07  W07  L07 SV07 ERA07
# 0    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  198.0  221   91   25  104   14   11    0  4.14
#
# [5 rows x 121 columns]

# %%
df8 = pd.merge(df7, season2008_df_new, on = ['PLAYER'], how = "outer")
df8.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH08  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...    0
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...    0
#
#     IP08  H08 ER08 BB08 SO08  W08  L08 SV08 ERA08
# 0    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  184.0  184   80   44  173   11   10    0  3.91
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  194.0  204   91   30   98    8   13    0  4.22
#
# [5 rows x 136 columns]

# %%
df9 = pd.merge(df8, season2009_df_new, on = ['PLAYER'], how = "outer")
df9.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH09  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP09  H09 ER09 BB09 SO09  W09  L09 SV09 ERA09
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 151 columns]

# %%
df10 = pd.merge(df9, season2010_df_new, on = ['PLAYER'], how = "outer")
df10.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH10  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP10  H10 ER10 BB10 SO10  W10  L10 SV10 ERA10
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 166 columns]

# %%
df11 = pd.merge(df10, season2011_df_new, on = ['PLAYER'], how = "outer")
df11.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH11  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP11  H11 ER11 BB11 SO11  W11  L11 SV11 ERA11
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 181 columns]

# %%
df12 = pd.merge(df11, season2012_df_new, on = ['PLAYER'], how = "outer")
df12.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH12  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP12  H12 ER12 BB12 SO12  W12  L12 SV12 ERA12
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 196 columns]

# %%
df13 = pd.merge(df12, season2013_df_new, on = ['PLAYER'], how = "outer")
df13.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH13  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP13  H13 ER13 BB13 SO13  W13  L13 SV13 ERA13
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 211 columns]

# %%
df14 = pd.merge(df13, season2014_df_new, on = ['PLAYER'], how = "outer")
df14.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH14  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP14  H14 ER14 BB14 SO14  W14  L14 SV14 ERA14
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 226 columns]

# %%
df15 = pd.merge(df14, season2015_df_new, on = ['PLAYER'], how = "outer")
df15.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH15  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP15  H15 ER15 BB15 SO15  W15  L15 SV15 ERA15
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 241 columns]

# %%
df16 = pd.merge(df15, season2016_df_new, on = ['PLAYER'], how = "outer")
df16.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH16  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP16  H16 ER16 BB16 SO16  W16  L16 SV16 ERA16
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 256 columns]

# %%
df17 = pd.merge(df16, season2017_df_new, on = ['PLAYER'], how = "outer")
df17.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH17  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP17  H17 ER17 BB17 SO17  W17  L17 SV17 ERA17
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 271 columns]

# %%
df18 = pd.merge(df17, season2018_df_new, on = ['PLAYER'], how = "outer")
df18.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH18  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP18  H18 ER18 BB18 SO18  W18  L18 SV18 ERA18
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 286 columns]

# %%
df19 = pd.merge(df18, season2019_df_new, on = ['PLAYER'], how = "outer")
df19.head()
# Out:
#   _x           PLAYER YRS00 G00 GS00 CG00 SH00   IP00  H00 ER00  ... SH19  \
# 0  1   Pedro Martinez    18  29   29    7    4  217.0  128   42  ...  NaN
# 1  2      Kevin Brown    19  33   33    5    1  230.0  181   66  ...  NaN
# 2  3    Randy Johnson    22  35   35    8    3  248.2  202   73  ...  NaN
# 3  4  Jeff C. D'Amico     8  23   23    1    1  162.1  143   48  ...  NaN
# 4  5      Greg Maddux    23  35   35    6    3  249.1  225   83  ...  NaN
#
#   IP19  H19 ER19 BB19 SO19  W19  L19 SV19 ERA19
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 301 columns]

# %%
df19.to_csv('merged_data.csv', index=False, sep=',', encoding='utf-8')
